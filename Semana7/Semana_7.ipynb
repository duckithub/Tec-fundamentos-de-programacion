# %%
archivo = open("archivo.txt", mode="w")
archivo.write("Si se puede escribir desde python\n")
archivo.close()
print("se ha escrito en el archivo",{archivo})
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 archivo = open("archivo.txt", mode="r")
#       2 archivo.write("Si se puede escribir desde python\n")
#       3 archivo.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'archivo.txt'

# %%
with open("bitacora.txt", mode="w") as archivo:
     archivo.write("Esta es la primer linea")

with open("bitacora.txt", mode="a") as archivo:
     archivo.write("linea")

# %%
nombre = input("ingrese su nombre: ")
edad = input("ingrese su edad: ")

with open("datos_usuario.txt", mode="w") as archivo:
    archivo.write(f"Nombre:{nombre}, Edad:{edad}\n")

print("datos guardados")

# %%
with open("LSIDHCO.txt", mode="w") as a:
    contenido = a.read()
    print("contenido")
