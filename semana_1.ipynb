# %% [markdown]
# # hello neighbour
# 1.6
# 2.7

# %% [markdown]
# Variables
#
# las variables en python son tipos de datos que tienen diferente forma
#
# -Numericas
#     -Enteros
#     -Flotantes
#
# -Cadena de caracteres
# -Booleanos
# -Compuestos
#
#
# COMO PASAR A PANDA A PYTHON
#
# import request
# import pandas as pd
#
# url="https://unstats.un.org/sdgapi/v1/sdg/Series/Data?seriesCode=SI_POV_DAY1&pageSize=100"
#
# response= request.get(url)
# data= response.json()
#
# df= pd.DataFrame(data["data"])
#
# df_clean= df[
#     ["geoAreaName","timePeriodStart","value"]
# ]
#
# print(
#     df_clean.head(50)
# )

# %% [markdown]
# ## Algoritmo para calcular velocidad

# %%
distancia = int(input("Ingrese la distancia en kilometros: "))
tiempo = int(input("Ingrese el tiempo en horas: "))

print("El dato de distancia es de tipo: ", type(distancia))
print("El dato de tiempo es de tipo: ", type(tiempo))

velocidad = distancia/tiempo

print("La velocidad promedio es: ", velocidad)

# %% [markdown]
# ## Operadores

# %%
a = 4 
b = 6 

print(a+b)
print(a == b)
print(a < b)
print(a != b)

# %% [markdown]
# ## Salu2
