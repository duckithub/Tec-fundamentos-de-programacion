# %% [markdown]
# ## Ejercicios semana 2 wowwowowow ( •̀ ω •́ )✧

# %%
#Ejercicio edad

edad = 17
if edad >= 18:
    print("Eres mayor de edad")
else:
    print("Eres menor de edad")
# Out:
# Eres menor de edad

# %%
edad = int(input("ingresa edad: "))

if not (edad < 0 ):
    print("hold on there partner there aint no one 0 years old ")
else:
    print("now thats something boe")

# %%
#Ejemplo calificaciones

calificacion= 20

if calificacion >= 90:
    print("A")
elif calificacion >= 80:
    print("B")
elif calificacion >= 70:
    print("C")
elif calificacion >= 60:
    print("D")
else:
    print("F")
# Out:
# F

# %%
#Operadores logicos

P1 = True
P2 = False

print(P1 and P2)
# Out:
# False

# %%
edad = 65

tipo = "adulto mayor"

mayor = edad >= 18
print(mayor)
descuento = (edad >=60) and (tipo == mayor)
print(descuento)
# Out:
# True
# False
